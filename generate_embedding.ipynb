# %% [markdown]
# # Generate embeddings with the OpenAI SDK

# %% [markdown]
# ## Set up the AzureOpenAI client
#
# Run the cell below if you are using Azure OpenAI with keyless auth and have already set up a .env file with the required variables.

# %%
import os

from azure.identity import AzureCliCredential, get_bearer_token_provider
import dotenv
import openai

dotenv.load_dotenv()

azure_credential = AzureCliCredential()
token_provider = get_bearer_token_provider(azure_credential, "https://cognitiveservices.azure.com/.default")
openai_client = openai.AzureOpenAI(
    api_version="2024-10-21",
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    azure_ad_token_provider=token_provider,
)
MODEL_NAME = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")

# %% [markdown]
# ## Set up the OpenAI client with GitHub Models
#
# Run the cell below if you are using OpenAI with GitHub Models. If you're running this in GitHub Codespaces, the GITHUB_TOKEN environment variable will already be set for you. If you're running this locally, make sure to set the GITHUB_TOKEN environment variable with a Personal Access Token (PAT) from GitHub.

# %%
import os
import openai

openai_client = openai.OpenAI(
    base_url="https://models.inference.ai.azure.com",
    api_key=os.environ["GITHUB_TOKEN"]
)
MODEL_NAME = "text-embedding-3-small"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 7
#       2 import os
#       3 import openai
#       5 openai_client = openai.OpenAI(
#       6     base_url="https://models.inference.ai.azure.com",
# ----> 7     api_key=os.environ["GITHUB_TOKEN"]
#       8 )
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: 'GITHUB_TOKEN'

# %%
embeddings_response = openai_client.embeddings.create(
    model=MODEL_NAME,
    input="hola mundo",
    dimensions=1536,
)
print(embeddings_response.data[0].embedding)
# Out:
# [0.023549066856503487, -0.0421622060239315, -0.023135440424084663, 0.006473235785961151, -0.01315328385680914, -0.01880616322159767, -0.036288727074861526, 0.07572100311517715, -0.07390104979276657, -0.03747444972395897, -0.010147606953978539, 0.002350770402699709, -0.008486212231218815, -0.02076398953795433, 0.01252595242112875, 0.04593998193740845, -0.03074614703655243, 0.019936738535761833, 0.004056974779814482, 0.03893592581152916, 0.017317112535238266, 0.005070356652140617, -0.008665449917316437, 0.02488645538687706, 0.005170315969735384, -0.0029126114677637815, -0.02845741994678974, 0.022901054471731186, 0.01924736425280571, -0.0266236811876297, 0.04977291077375412, -0.051482561975717545, -0.010643957182765007, 0.013821978121995926, -0.02738199383020401, -0.019164638593792915, 4.1981889808084816e-05, 0.009092862717807293, 0.0037605431862175465, -0.024307379499077797, 0.0057631791569292545, 0.005290956702083349, 0.027037305757403374, 0.06005839258432388, -0.003072891151532531, -0.01935766451060772, -0.07053689658641815, 0.0018751013558357954, 0.06441524624824524, 0.04398215562105179, -0.006545620039105415, -0.016172748059034348, 0.023562854155898094, 0.16489861905574799, 0.033586375415325165, -0.018957825377583504, 0.014752635732293129, 0.02634793147444725, -0.03945985436439514, 0.01087145134806633, -0.0016915551386773586, -0.0021801500115543604, 0.03755717724561691, 0.019233576953411102, 0.03030494600534439, -0.007231548894196749, -0.03138037025928497, 0.01686212420463562, -0.026416867971420288, 0.022969990968704224, -0.038301702588796616, 0.051096510142087936, -0.02379724197089672, -0.02352149225771427, -0.032014597207307816, -0.009547850117087364, -0.044368207454681396, -0.0034348133485764265, -0.013284265995025635, -0.02407299168407917, -0.042272504419088364, 0.013925384730100632, -0.014849147759377956, -0.03979075327515602, -0.0001457382895750925, 0.03951500356197357, -0.039763178676366806, 0.009609893895685673, 0.01810299977660179, 0.0011521187843754888, 0.009589212946593761, 0.011953771114349365, -0.012670721858739853, 0.032345496118068695, 0.03237307444214821, -0.0015648823464289308, -0.028264394029974937, 0.020860502496361732, 0.07064720243215561, -0.043017029762268066, 0.02629278041422367, -0.03286942467093468, -0.00878264382481575, -0.02081913873553276, -0.0007496958132833242, -0.00031538927578367293, -0.00034210257581435144, -0.0250519048422575, -0.021880777552723885, 0.0188613124191761, -0.040369827300310135, -0.0058424570597708225, 0.007920924574136734, -0.02667883038520813, 0.03215247392654419, 0.046656932681798935, 0.10467477142810822, -0.06413949280977249, 0.05746633931994438, -0.03297972306609154, 0.010740470141172409, -0.027188969776034355, 0.016613949090242386, -0.019757501780986786, -0.07114355266094208, -0.027133818715810776, -0.013270477764308453, 0.033420924097299576, -0.02239091508090496, -0.008424168452620506, -0.0027230330742895603, 0.02174290269613266, 0.0002863062545657158, -0.03805352747440338, -0.012980940751731396, 0.032014597207307816, -0.01632441207766533, -0.0319870226085186, -0.06110624223947525, 0.022542579099535942, 0.03535117581486702, -0.03653690218925476, -0.020805351436138153, -0.0002970777568407357, -0.005759732332080603, -0.018792375922203064, 0.006311232689768076, 0.043678831309080124, 0.007383211515843868, -0.007817517966032028, 0.01509732287377119, 0.023466341197490692, -0.04538848251104355, 0.001776865334250033, 0.014807785861194134, -0.02445904165506363, 0.006090632639825344, -0.03524087369441986, -0.005994119681417942, 0.025851581245660782, 0.02612733095884323, 0.0018044402822852135, -0.028319545090198517, -0.002064679516479373, -0.009982156567275524, 0.0204330887645483, -0.043623682111501694, 0.015069748274981976, -0.049855634570121765, 0.017068937420845032, -0.0023180251009762287, 0.019316300749778748, -0.04574695602059364, -0.01870965026319027, 0.012532846070826054, 0.021715328097343445, 0.033862125128507614, -0.052778586745262146, -0.02418329194188118, 0.01342214085161 ...
